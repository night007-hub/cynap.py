# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/animeface007/gan.zip/21130.png
# /kaggle/input/animeface007/gan.zip/9273.png
# /kaggle/input/animeface007/gan.zip/18966.png
# /kaggle/input/animeface007/gan.zip/14127.png
# /kaggle/input/animeface007/gan.zip/18054.png
# /kaggle/input/animeface007/gan.zip/9292.png
# /kaggle/input/animeface007/gan.zip/11396.png
# /kaggle/input/animeface007/gan.zip/14260.png
# /kaggle/input/animeface007/gan.zip/4353.png
# /kaggle/input/animeface007/gan.zip/7968.png
# /kaggle/input/animeface007/gan.zip/15834.png
# /kaggle/input/animeface007/gan.zip/6490.png
# /kaggle/input/animeface007/gan.zip/5511.png
# /kaggle/input/animeface007/gan.zip/6262.png
# /kaggle/input/animeface007/gan.zip/2664.png
# /kaggle/input/animeface007/gan.zip/12329.png
# /kaggle/input/animeface007/gan.zip/17678.png
# /kaggle/input/animeface007/gan.zip/8419.png
# /kaggle/input/animeface007/gan.zip/9703.png
# /kaggle/input/animeface007/gan.zip/13412.png
# /kaggle/input/animeface007/gan.zip/14325.png
# /kaggle/input/animeface007/gan.zip/18315.png
# /kaggle/input/animeface007/gan.zip/15055.png
# /kaggle/input/animeface007/gan.zip/2539.png
# /kaggle/input/animeface007/gan.zip/9110.png
# /kaggle/input/animeface007/gan.zip/5703.png
# /kaggle/input/animeface007/gan.zip/21515.png
# /kaggle/input/animeface007/gan.zip/13139.png
# /kaggle/input/animeface007/gan.zip/1231.png
# /kaggle/input/animeface007/gan.zip/18299.png
# /kaggle/input/animeface007/gan.zip/16020.png
# /kaggle/input/animeface007/gan.zip/20474.png
# /kaggle/input/animeface007/gan.zip/20634.png
# /kaggle/input/animeface007/gan.zip/1017.png
# /kaggle/input/animeface007/gan.zip/4803.png
# /kaggle/input/animeface007/gan.zip/20985.png
# /kaggle/input/animeface007/gan.zip/17778.png
# /kaggle/input/animeface007/gan.zip/7197.png
# /kaggle/input/animeface007/gan.zip/16257.png
# /kaggle/input/animeface007/gan.zip/12743.png
# /kaggle/input/animeface007/gan.zip/14990.png
# /kaggle/input/animeface007/gan.zip/16765.png
# /kaggle/input/animeface007/gan.zip/10760.png
# /kaggle/input/animeface007/gan.zip/2437.png
# /kaggle/input/animeface007/gan.zip/16552.png
# /kaggle/input/animeface007/gan.zip/7530.png
# /kaggle/input/animeface007/gan.zip/3217.png
# /kaggle/input/animeface007/gan.zip/5695.png
# /kaggle/input/animeface007/gan.zip/12867.png
# /kaggle/input/animeface007/gan.zip/20028.png
# /kaggle/input/animeface007/gan.zip/19786.png
# /kaggle/input/animeface007/gan.zip/8565.png
# /kaggle/input/animeface007/gan.zip/13570.png
# /kaggle/input/animeface007/gan.zip/6441.png
# /kaggle/input/animeface007/gan.zip/6692.png
# /kaggle/input/animeface007/gan.zip/17206.png
# /kaggle/input/animeface007/gan.zip/5106.png
# /kaggle/input/animeface007/gan.zip/21221.png
# /kaggle/input/animeface007/gan.zip/5590.png
# /kaggle/input/animeface007/gan.zip/21296.png
# /kaggle/input/animeface007/gan.zip/16921.png
# /kaggle/input/animeface007/gan.zip/3207.png
# /kaggle/input/animeface007/gan.zip/2015.png
# /kaggle/input/animeface007/gan.zip/2300.png
# /kaggle/input/animeface007/gan.zip/2673.png
# /kaggle/input/animeface007/gan.zip/2823.png
# /kaggle/input/animeface007/gan.zip/3765.png
# /kaggle/input/animeface007/gan.zip/17394.png
# /kaggle/input/animeface007/gan.zip/15424.png
# /kaggle/input/animeface007/gan.zip/1522.png
# /kaggle/input/animeface007/gan.zip/4747.png
# /kaggle/input/animeface007/gan.zip/6720.png
# /kaggle/input/animeface007/gan.zip/17364.png
# /kaggle/input/animeface007/gan.zip/12684.png
# /kaggle/input/animeface007/gan.zip/17873.png
# /kaggle/input/animeface007/gan.zip/13612.png
# /kaggle/input/animeface007/gan.zip/9938.png
# /kaggle/input/animeface007/gan.zip/6811.png
# /kaggle/input/animeface007/gan.zip/12204.png
# /kaggle/input/animeface007/gan.zip/13159.png
# /kaggle/input/animeface007/gan.zip/18584.png
# /kaggle/input/animeface007/gan.zip/21399.png
# /kaggle/input/animeface007/gan.zip/10188.png
# /kaggle/input/animeface007/gan.zip/3824.png
# /kaggle/input/animeface007/gan.zip/15992.png
# /kaggle/input/animeface007/gan.zip/11953.png
# /kaggle/input/animeface007/gan.zip/12956.png
# /kaggle/input/animeface007/gan.zip/7726.png
# /kaggle/input/animeface007/gan.zip/6131.png
# /kaggle/input/animeface007/gan.zip/4358.png
# /kaggle/input/animeface007/gan.zip/2064.png
# /kaggle/input/animeface007/gan.zip/6456.png
# /kaggle/input/animeface007/gan.zip/18775.png
# /kaggle/input/animeface007/gan.zip/12139.png
# /kaggle/input/animeface007/gan.zip/641.png
# /kaggle/input/animeface007/gan.zip/12727.png
# /kaggle/input/animeface007/gan.zip/19009.png
# /kaggle/input/animeface007/gan.zip/14516.png
# /kaggle/input/animeface007/gan.zip/7324.png
# /kaggle/input/animeface007/gan.zip/11572.png
# /kaggle/input/animeface007/gan.zip/19864.png
# /kaggle/input/animeface007/gan.zip/1088.png
# /kaggle/input/animeface007/gan.zip/17374.png
# /kaggle/input/animeface007/gan.zip/173.png
# /kaggle/input/animeface007/gan.zip/16360.png
# /kaggle/input/animeface007/gan.zip/5100.png
# /kaggle/input/animeface007/gan.zip/7863.png
# /kaggle/input/animeface007/gan.zip/9246.png
# /kaggle/input/animeface007/gan.zip/2851.png
# /kaggle/input/animeface007/gan.zip/6875.png
# /kaggle/input/animeface007/gan.zip/8414.png
# /kaggle/input/animeface007/gan.zip/8841.png
# /kaggle/input/animeface007/gan.zip/11070.png
# /kaggle/input/animeface007/gan.zip/2448.png
# /kaggle/input/animeface007/gan.zip/7992.png
# /kaggle/input/animeface007/gan.zip/11927.png
# /kaggle/input/animeface007/gan.zip/7290.png
# /kaggle/input/animeface007/gan.zip/7334.png
# /kaggle/input/animeface007/gan.zip/9982.png
# /kaggle/input/animeface007/gan.zip/19124.png
# /kaggle/input/animeface007/gan.zip/17329.png
# /kaggle/input/animeface007/gan.zip/19318.png
# /kaggle/input/animeface007/gan.zip/18929.png
# /kaggle/input/animeface007/gan.zip/1746.png
# /kaggle/input/animeface007/gan.zip/9334.png
# /kaggle/input/animeface007/gan.zip/10107.png
# /kaggle/input/animeface007/gan.zip/9621.png
# /kaggle/input/animeface007/gan.zip/13744.png
# /kaggle/input/animeface007/gan.zip/1958.png
# /kaggle/input/animeface007/gan.zip/13907.png
# /kaggle/input/animeface007/gan.zip/14555.png
# /kaggle/input/animeface007/gan.zip/1479.png
# /kaggle/input/animeface007/gan.zip/7418.png
# /kaggle/input/animeface007/gan.zip/15221.png
# /kaggle/input/animeface007/gan.zip/16617.png
# /kaggle/input/animeface007/gan.zip/9288.png
# /kaggle/input/animeface007/gan.zip/12470.png
# /kaggle/input/animeface007/gan.zip/8426.png
# /kaggle/input/animeface007/gan.zip/6859.png
# /kaggle/input/animeface007/gan.zip/13513.png
# /kaggle/input/animeface007/gan.zip/19018.png
# /kaggle/input/animeface007/gan.zip/7134.png
# /kaggle/input/animeface007/gan.zip/17002.png
# /kaggle/input/animeface007/gan.zip/9767.png
# /kaggle/input/animeface007/gan.zip/9570.png
# /kaggle/input/animeface007/gan.zip/7633.png
# /kaggle/input/animeface007/gan.zip/21512.png
# /kaggle/input/animeface007/gan.zip/18596.png
# /kaggle/input/animeface007/gan.zip/13964.png
# /kaggle/input/animeface007/gan.zip/815.png
# /kaggle/input/animeface007/gan.zip/4352.png
# /kaggle/input/animeface007/gan.zip/3448.png
# /kaggle/input/animeface007/gan.zip/11901.png
# /kaggle/input/animeface007/gan.zip/11711.png
# /kaggle/input/animeface007/gan.zip/1794.png
# /kaggle/input/animeface007/gan.zip/1727.png
# /kaggle/input/animeface007/gan.zip/10696.png
# /kaggle/input/animeface007/gan.zip/7780.png
# /kaggle/input/animeface007/gan.zip/8987.png
# /kaggle/input/animeface007/gan.zip/1684.png
# /kaggle/input/animeface007/gan.zip/17487.png
# /kaggle/input/animeface007/gan.zip/4685.png
# /kaggle/input/animeface007/gan.zip/11506.png
# /kaggle/input/animeface007/gan.zip/4649.png
# /kaggle/input/animeface007/gan.zip/15341.png
# /kaggle/input/animeface007/gan.zip/15542.png
# /kaggle/input/animeface007/gan.zip/14202.png
# /kaggle/input/animeface007/gan.zip/17662.png
# /kaggle/input/animeface007/gan.zip/15708.png
# /kaggle/input/animeface007/gan.zip/17728.png
# /kaggle/input/animeface007/gan.zip/7236.png
# /kaggle/input/animeface007/gan.zip/17971.png
# /kaggle/input/animeface007/gan.zip/13767.png
# /kaggle/input/animeface007/gan.zip/13009.png
# /kaggle/input/animeface007/gan.zip/20719.png
# /kaggle/input/animeface007/gan.zip/9390.png
# /kaggle/input/animeface007/gan.zip/5184.png
# /kaggle/input/animeface007/gan.zip/14348.png
# /kaggle/input/animeface007/gan.zip/21158.png
# /kaggle/input/animeface007/gan.zip/10124.png
# /kaggle/input/animeface007/gan.zip/20137.png
# /kaggle/input/animeface007/gan.zip/9956.png
# /kaggle/input/animeface007/gan.zip/1814.png
# /kaggle/input/animeface007/gan.zip/21194.png
# /kaggle/input/animeface007/gan.zip/13691.png
# /kaggle/input/animeface007/gan.zip/491.png
# /kaggle/input/animeface007/gan.zip/9620.png
# /kaggle/input/animeface007/gan.zip/15256.png
# /kaggle/input/animeface007/gan.zip/2982.png
# /kaggle/input/animeface007/gan.zip/10316.png
# /kaggle/input/animeface007/gan.zip/21166.png
# /kaggle/input/animeface007/gan.zip/11246.png
# /kaggle/input/animeface007/gan.zip/20963.png
# /kaggle/input/animeface007/gan.zip/8281.png
# /kaggle/input/animeface007/gan.zip/2276.png
# /kaggle/input/animeface007/gan.zip/14502.png
# /kaggle/input/animeface007/gan.zip/1457.png
# /kaggle/input/animeface007/gan.zip/13679.png
# /kaggle/input/animeface007/gan.zip/3152.png
# /kaggle/input/animeface007/gan.zip/4319.png
# /kaggle/input/animeface007/gan.zip/8669.png
# /kaggle/input/animeface007/gan.zip/1924.png
# /kaggle/input/animeface007/gan.zip/13556.png
# /kaggle/input/animeface007/gan.zip/4805.png
# /kaggle/input/animeface007/gan.zip/9243.png
# /kaggle/input/animeface007/gan.zip/17604.png
# /kaggle/input/animeface007/gan.zip/17451.png
# /kaggle/input/animeface007/gan.zip/1084.png
# /kaggle/input/animeface007/gan.zip/14750.png
# /kaggle/input/animeface007/gan.zip/14993.png
# /kaggle/input/animeface007/gan.zip/15498.png
# /kaggle/input/animeface007/gan.zip/11695.png
# /kaggle/input/animeface007/gan.zip/10106.png
# /kaggle/input/animeface007/gan.zip/5109.png
# /kaggle/input/animeface007/gan.zip/18195.png
# /kaggle/input/animeface007/gan.zip/7714.png
# /kaggle/input/animeface007/gan.zip/8343.png
# /kaggle/input/animeface007/gan.zip/718.png
# /kaggle/input/animeface007/gan.zip/13018.png
# /kaggle/input/animeface007/gan.zip/12631.png
# /kaggle/input/animeface007/gan.zip/3722.png
# /kaggle/input/animeface007/gan.zip/16585.png
# /kaggle/input/animeface007/gan.zip/709.png
# /kaggle/input/animeface007/gan.zip/19052.png
# /kaggle/input/animeface007/gan.zip/11196.png
# /kaggle/input/animeface007/gan.zip/10496.png
# /kaggle/input/animeface007/gan.zip/13908.png
# /kaggle/input/animeface007/gan.zip/9662.png
# /kaggle/input/animeface007/gan.zip/16235.png
# /kaggle/input/animeface007/gan.zip/2690.png
# /kaggle/input/animeface007/gan.zip/6683.png
# /kaggle/input/animeface007/gan.zip/13644.png
# /kaggle/input/animeface007/gan.zip/889.png
# /kaggle/input/animeface007/gan.zip/13314.png
# /kaggle/input/animeface007/gan.zip/8062.png
# /kaggle/input/animeface007/gan.zip/13337.png
# /kaggle/input/animeface007/gan.zip/17638.png
# /kaggle/input/animeface007/gan.zip/10149.png
# /kaggle/input/animeface007/gan.zip/20610.png
# /kaggle/input/animeface007/gan.zip/13696.png
# /kaggle/input/animeface007/gan.zip/10563.png
# /kaggle/input/animeface007/gan.zip/9995.png
# /kaggle/input/animeface007/gan.zip/9890.png
# /kaggle/input/animeface007/gan.zip/379.png
# /kaggle/input/animeface007/gan.zip/19616.png
# /kaggle/input/animeface007/gan.zip/18461.png
# /kaggle/input/animeface007/gan.zip/19372.png
# /kaggle/input/animeface007/gan.zip/16615.png
# /kaggle/input/animeface007/gan.zip/780.png
# /kaggle/input/animeface007/gan.zip/15061.png
# /kaggle/input/animeface007/gan.zip/7257.png
# /kaggle/input/animeface007/gan.zip/3244.png
# /kaggle/input/animeface007/gan.zip/8514.png
# /kaggle/input/animeface007/gan.zip/6595.png
# /kaggle/input/animeface007/gan.zip/16458.png
# /kaggle/input/animeface007/gan.zip/13235.png
# /kaggle/input/animeface007/gan.zip/20595.png
# /kaggle/input/animeface007/gan.zip/18983.png
# /kaggle/input/animeface007/gan.zip/248.png
# /kaggle/input/animeface007/gan.zip/11208.png
# /kaggle/input/animeface007/gan.zip/7621.png
# /kaggle/input/animeface007/gan.zip/8947.png
# /kaggle/input/animeface007/gan.zip/10163.png
# /kaggle/input/animeface007/gan.zip/9706.png
# /kaggle/input/animeface007/gan.zip/16231.png
# /kaggle/input/animeface007/gan.zip/10628.png
# /kaggle/input/animeface007/gan.zip/21286.png
# /kaggle/input/animeface007/gan.zip/8231.png
# /kaggle/input/animeface007/gan.zip/15666.png
# /kaggle/input/animeface007/gan.zip/12757.png
# /kaggle/input/animeface007/gan.zip/5073.png
# /kaggle/input/animeface007/gan.zip/11970.png
# /kaggle/input/animeface007/gan.zip/20800.png
# /kaggle/input/animeface007/gan.zip/16079.png
# /kaggle/input/animeface007/gan.zip/9980.png
# /kaggle/input/animeface007/gan.zip/13822.png
# /kaggle/input/animeface007/gan.zip/20638.png
# /kaggle/input/animeface007/gan.zip/13385.png
# /kaggle/input/animeface007/gan.zip/15685.png
# /kaggle/input/animeface007/gan.zip/1680.png
# /kaggle/input/animeface007/gan.zip/18903.png
# /kaggle/input/animeface007/gan.zip/1675.png
# /kaggle/input/animeface007/gan.zip/2619.png
# /kaggle/input/animeface007/gan.zip/6299.png
# /kaggle/input/animeface007/gan.zip/6971.png
# /kaggle/input/animeface007/gan.zip/9650.png
# /kaggle/input/animeface007/gan.zip/4023.png
# /kaggle/input/animeface007/gan.zip/10272.png
# /kaggle/input/animeface007/gan.zip/15575.png
# /kaggle/input/animeface007/gan.zip/9791.png
# /kaggle/input/animeface007/gan.zip/2273.png
# /kaggle/input/animeface007/gan.zip/15069.png
# /kaggle/input/animeface007/gan.zip/4800.png
# /kaggle/input/animeface007/gan.zip/5028.png
# /kaggle/input/animeface007/gan.zip/7432.png
# /kaggle/input/animeface007/gan.zip/13281.png
# /kaggle/input/animeface007/gan.zip/94.png
# /kaggle/input/animeface007/gan.zip/9633.png
# /kaggle/input/animeface007/gan.zip/10062.png
# /kaggle/input/animeface007/gan.zip/7119.png
# /kaggle/input/animeface007/gan.zip/2969.png
# /kaggle/input/animeface007/gan.zip/15449.png
# /kaggle/input/animeface007/gan.zip/10054.png
# /kaggle/input/animeface007/gan.zip/12356.png
# /kaggle/input/animeface007/gan.zip/21173.png
# /kaggle/input/animeface007/gan.zip/9914.png
# /kaggle/input/animeface007/gan.zip/3379.png
# /kaggle/input/animeface007/gan.zip/16790.png
# /kaggle/input/animeface007/gan.zip/2772.png
# /kaggle/input/animeface007/gan.zip/19511.png
# /kaggle/input/animeface007/gan.zip/19353.png
# /kaggle/input/animeface007/gan.zip/14037.png
# /kaggle/input/animeface007/gan.zip/7105.png
# /kaggle/input/animeface007/gan.zip/13398.png
# /kaggle/input/animeface007/gan.zip/15278.png
# /kaggle/input/animeface007/gan.zip/480.png
# /kaggle/input/animeface007/gan.zip/10493.png
# /kaggle/input/animeface007/gan.zip/8794.png
# /kaggle/input/animeface007/gan.zip/7753.png
# /kaggle/input/animeface007/gan.zip/6645.png
# /kaggle/input/animeface007/gan.zip/3550.png
# /kaggle/input/animeface007/gan.zip/19785.png
# /kaggle/input/animeface007/gan.zip/5567.png
# /kaggle/input/animeface007/gan.zip/2256.png
# /kaggle/input/animeface007/gan.zip/12876.png
# /kaggle/input/animeface007/gan.zip/5918.png
# /kaggle/input/animeface007/gan.zip/15213.png
# /kaggle/input/animeface007/gan.zip/18431.png
# /kaggle/input/animeface007/gan.zip/21548.png
# /kaggle/input/animeface007/gan.zip/1145.png
# /kaggle/input/animeface007/gan.zip/6978.png
# /kaggle/input/animeface007/gan.zip/9679.png
# /kaggle/input/animeface007/gan.zip/7395.png
# /kaggle/input/animeface007/gan.zip/11549.png
# /kaggle/input/animeface007/gan.zip/3295.png
# /kaggle/input/animeface007/gan.zip/18802.png
# /kaggle/input/animeface007/gan.zip/20770.png
# /kaggle/input/animeface007/gan.zip/5950.png
# /kaggle/input/animeface007/gan.zip/13812.png
# /kaggle/input/animeface007/gan.zip/17126.png
# /kaggle/input/animeface007/gan.zip/10759.png
# /kaggle/input/animeface007/gan.zip/12429.png
# /kaggle/input/animeface007/gan.zip/15979.png
# /kaggle/input/animeface007/gan.zip/2021.png
# /kaggle/input/animeface007/gan.zip/1944.png
# /kaggle/input/animeface007/gan.zip/11659.png
# /kaggle/input/animeface007/gan.zip/6423.png
# /kaggle/input/animeface007/gan.zip/3569.png
# /kaggle/input/animeface007/gan.zip/7166.png
# /kaggle/input/animeface007/gan.zip/6630.png
# /kaggle/input/animeface007/gan.zip/15872.png
# /kaggle/input/animeface007/gan.zip/6536.png
# /kaggle/input/animeface007/gan.zip/16053.png
# /kaggle/input/animeface007/gan.zip/3685.png
# /kaggle/input/animeface007/gan.zip/9088.png
# /kaggle/input/animeface007/gan.zip/21450.png
# /kaggle/input/animeface007/gan.zip/7592.png
# /kaggle/input/animeface007/gan.zip/9225.png
# /kaggle/input/animeface007/gan.zip/17833.png
# /kaggle/input/animeface007/gan.zip/10104.png
# /kaggle/input/animeface007/gan.zip/21178.png
# /kaggle/input/animeface007/gan.zip/9847.png
# /kaggle/input/animeface007/gan.zip/8685.png
# /kaggle/input/animeface007/gan.zip/7601.png
# /kaggle/input/animeface007/gan.zip/236.png
# /kaggle/input/animeface007/gan.zip/3890.png
# /kaggle/input/animeface007/gan.zip/8526.png
# /kaggle/input/animeface007/gan.zip/13578.png
# /kaggle/input/animeface007/gan.zip/11822.png
# /kaggle/input/animeface007/gan.zip/14686.png
# /kaggle/input/animeface007/gan.zip/16175.png
# /kaggle/input/animeface007/gan.zip/18555.png
# /kaggle/input/animeface007/gan.zip/6255.png
# /kaggle/input/animeface007/gan.zip/13404.png
# /kaggle/input/animeface007/gan.zip/1012.png
# /kaggle/input/animeface007/gan.zip/9512.png
# /kaggle/input/animeface007/gan.zip/21126.png
# /kaggle/input/animeface007/gan.zip/12381.png
# /kaggle/input/animeface007/gan.zip/2970.png
# /kaggle/input/animeface007/gan.zip/11766.png
# /kaggle/input/animeface007/gan.zip/2518.png
# /kaggle/input/animeface007/gan.zip/19638.png
# /kaggle/input/animeface007/gan.zip/12490.png
# /kaggle/input/animeface007/gan.zip/2176.png
# /kaggle/input/animeface007/gan.zip/16853.png
# /kaggle/input/animeface007/gan.zip/19482.png
# /kaggle/input/animeface007/gan.zip/14022.png
# /kaggle/input/animeface007/gan.zip/8906.png
# /kaggle/input/animeface007/gan.zip/9455.png
# /kaggle/input/animeface007/gan.zip/15065.png
# /kaggle/input/animeface007/gan.zip/1343.png
# /kaggle/input/animeface007/gan.zip/6014.png
# /kaggle/input/animeface007/gan.zip/17471.png
# /kaggle/input/animeface007/gan.zip/19933.png
# /kaggle/input/animeface007/gan.zip/8790.png
# /kaggle/input/animeface007/gan.zip/19966.png
# /kaggle/input/animeface007/gan.zip/14212.png
# /kaggle/input/animeface007/gan.zip/2347.png
# /kaggle/input/animeface007/gan.zip/19378.png
# /kaggle/input/animeface007/gan.zip/19347.png
# /kaggle/input/animeface007/gan.zip/771.png
# /kaggle/input/animeface007/gan.zip/20386.png
# /kaggle/input/animeface007/gan.zip/9240.png
# /kaggle/input/animeface007/gan.zip/10626.png
# /kaggle/input/animeface007/gan.zip/12056.png
# /kaggle/input/animeface007/gan.zip/20784.png
# /kaggle/input/animeface007/gan.zip/7488.png
# /kaggle/input/animeface007/gan.zip/2884.png
# /kaggle/input/animeface007/gan.zip/17325.png
# /kaggle/input/animeface007/gan.zip/13521.png
# /kaggle/input/animeface007/gan.zip/11006.png
# /kaggle/input/animeface007/gan.zip/12412.png
# /kaggle/input/animeface007/gan.zip/4770.png
# /kaggle/input/animeface007/gan.zip/15954.png
# /kaggle/input/animeface007/gan.zip/14702.png
# /kaggle/input/animeface007/gan.zip/2631.png
# /kaggle/input/animeface007/gan.zip/6199.png
# /kaggle/input/animeface007/gan.zip/21490.png
# /kaggle/input/animeface007/gan.zip/10299.png
# /kaggle/input/animeface007/gan.zip/7079.png
# /kaggle/input/animeface007/gan.zip/13416.png
# /kaggle/input/animeface007/gan.zip/8811.png
# /kaggle/input/animeface007/gan.zip/675.png
# /kaggle/input/animeface007/gan.zip/14173.png
# /kaggle/input/animeface007/gan.zip/16281.png
# /kaggle/input/animeface007/gan.zip/7360.png
# /kaggle/input/animeface007/gan.zip/340.png
# /kaggle/input/animeface007/gan.zip/48.png
# /kaggle/input/animeface007/gan.zip/9748.png
# /kaggle/input/animeface007/gan.zip/3952.png
# /kaggle/input/animeface007/gan.zip/12468.png
# /kaggle/input/animeface007/gan.zip/10797.png
# /kaggle/input/animeface007/gan.zip/6059.png
# /kaggle/input/animeface007/gan.zip/2525.png
# /kaggle/input/animeface007/gan.zip/9774.png
# /kaggle/input/animeface007/gan.zip/15389.png
# /kaggle/input/animeface007/gan.zip/15535.png
# /kaggle/input/animeface007/gan.zip/10874.png
# /kaggle/input/animeface007/gan.zip/3012.png
# /kaggle/input/animeface007/gan.zip/17478.png
# /kaggle/input/animeface007/gan.zip/1948.png
# /kaggle/input/animeface007/gan.zip/4518.png
# /kaggle/input/animeface007/gan.zip/10897.png
# /kaggle/input/animeface007/gan.zip/20851.png
# /kaggle/input/animeface007/gan.zip/17209.png
# /kaggle/input/animeface007/gan.zip/1878.png
# /kaggle/input/animeface007/gan.zip/19500.png
# /kaggle/input/animeface007/gan.zip/20564.png
# /kaggle/input/animeface007/gan.zip/7302.png
# /kaggle/input/animeface007/gan.zip/9792.png
# /kaggle/input/animeface007/gan.zip/11251.png
# /kaggle/input/animeface007/gan.zip/12022.png
# /kaggle/input/animeface007/gan.zip/14703.png
# /kaggle/input/animeface007/gan.zip/7316.png
# /kaggle/input/animeface007/gan.zip/12525.png
# /kaggle/input/animeface007/gan.zip/15552.png
# /kaggle/input/animeface007/gan.zip/12032.png
# /kaggle/input/animeface007/gan.zip/10972.png
# /kaggle/input/animeface007/gan.zip/2211.png
# /kaggle/input/animeface007/gan.zip/10501.png
# /kaggle/input/animeface007/gan.zip/20070.png
# /kaggle/input/animeface007/gan.zip/9737.png
# /kaggle/input/animeface007/gan.zip/10829.png
# /kaggle/input/animeface007/gan.zip/12105.png
# /kaggle/input/animeface007/gan.zip/513.png
# /kaggle/input/animeface007/gan.zip/2947.png
# /kaggle/input/animeface007/gan.zip/7269.png
# /kaggle/input/animeface007/gan.zip/3917.png
# /kaggle/input/animeface007/gan.zip/10799.png
# /kaggle/input/animeface007/gan.zip/20625.png
# /kaggle/input/animeface007/gan.zip/17391.png
# /kaggle/input/animeface007/gan.zip/19406.png
# /kaggle/input/animeface007/gan.zip/13952.png
# /kaggle/input/animeface007/gan.zip/13054.png
# /kaggle/input/animeface007/gan.zip/11874.png
# /kaggle/input/animeface007/gan.zip/20279.png
# /kaggle/input/animeface007/gan.zip/2976.png
# /kaggle/input/animeface007/gan.zip/21398.png
# /kaggle/input/animeface007/gan.zip/18252.png
# /kaggle/input/animeface007/gan.zip/8146.png
# /kaggle/input/animeface007/gan.zip/20678.png
# /kaggle/input/animeface007/gan.zip/15550.png
# /kaggle/input/animeface007/gan.zip/12004.png
# /kaggle/input/animeface007/gan.zip/3510.png
# /kaggle/input/animeface007/gan.zip/14448.png
# /kaggle/input/animeface007/gan.zip/1037.png
# /kaggle/input/animeface007/gan.zip/20794.png
# /kaggle/input/animeface007/gan.zip/13690.png
# /kaggle/input/animeface007/gan.zip/18218.png
# /kaggle/input/animeface007/gan.zip/17145.png
# /kaggle/input/animeface007/gan.zip/9596.png
# /kaggle/input/animeface007/gan.zip/8958.png
# /kaggle/input/animeface007/gan.zip/4511.png
# /kaggle/input/animeface007/gan.zip/14395.png
# /kaggle/input/animeface007/gan.zip/19838.png
# /kaggle/input/animeface007/gan.zip/677.png
# /kaggle/input/animeface007/gan.zip/14490.png
# /kaggle/input/animeface007/gan.zip/19969.png
# /kaggle/input/animeface007/gan.zip/5593.png
# /kaggle/input/animeface007/gan.zip/14236.png
# /kaggle/input/animeface007/gan.zip/13482.png
# /kaggle/input/animeface007/gan.zip/15444.png
# /kaggle/input/animeface007/gan.zip/19428.png
# /kaggle/input/animeface007/gan.zip/19276.png
# /kaggle/input/animeface007/gan.zip/6687.png
# /kaggle/input/animeface007/gan.zip/350.png
# /kaggle/input/animeface007/gan.zip/15952.png
# /kaggle/input/animeface007/gan.zip/19906.png
# /kaggle/input/animeface007/gan.zip/16317.png
# /kaggle/input/animeface007/gan.zip/16893.png
# /kaggle/input/animeface007/gan.zip/9445.png
# /kaggle/input/animeface007/gan.zip/2009.png
# /kaggle/input/animeface007/gan.zip/20847.png
# /kaggle/input/animeface007/gan.zip/20433.png
# /kaggle/input/animeface007/gan.zip/761.png
# /kaggle/input/animeface007/gan.zip/1258.png
# /kaggle/input/animeface007/gan.zip/8639.png
# /kaggle/input/animeface007/gan.zip/19984.png
# /kaggle/input/animeface007/gan.zip/17450.png
# /kaggle/input/animeface007/gan.zip/3362.png
# /kaggle/input/animeface007/gan.zip/9444.png
# /kaggle/input/animeface007/gan.zip/18437.png
# /kaggle/input/animeface007/gan.zip/19289.png
# /kaggle/input/animeface007/gan.zip/20590.png
# /kaggle/input/animeface007/gan.zip/8251.png
# /kaggle/input/animeface007/gan.zip/9976.png
# /kaggle/input/animeface007/gan.zip/17672.png
# /kaggle/input/animeface007/gan.zip/8897.png
# /kaggle/input/animeface007/gan.zip/4792.png
# /kaggle/input/animeface007/gan.zip/4916.png
# /kaggle/input/animeface007/gan.zip/2565.png
# /kaggle/input/animeface007/gan.zip/7136.png
# /kaggle/input/animeface007/gan.zip/12034.png
# /kaggle/input/animeface007/gan.zip/12305.png
# /kaggle/input/animeface007/gan.zip/18420.png
# /kaggle/input/animeface007/gan.zip/14743.png
# /kaggle/input/animeface007/gan.zip/9063.png
# /kaggle/input/animeface007/gan.zip/3363.png
# /kaggle/input/animeface007/gan.zip/8302.png
# /kaggle/input/animeface007/gan.zip/19220.png
# /kaggle/input/animeface007/gan.zip/11322.png
# /kaggle/input/animeface007/gan.zip/15782.png
# /kaggle/input/animeface007/gan.zip/6632.png
# /kaggle/input/animeface007/gan.zip/314.png
# /kaggle/input/animeface007/gan.zip/5197.png
# /kaggle/input/animeface007/gan.zip/3544.png
# /kaggle/input/animeface007/gan.zip/19912.png
# /kaggle/input/animeface007/gan.zip/15137.png
# /kaggle/input/animeface007/gan.zip/11457.png
# /kaggle/input/animeface007/gan.zip/20039.png
# /kaggle/input/animeface007/gan.zip/9785.png
# /kaggle/input/animeface007/gan.zip/12920.png
# /kaggle/input/animeface007/gan.zip/10597.png
# /kaggle/input/animeface007/gan.zip/1023.png
# /kaggle/input/animeface007/gan.zip/18969.png
# /kaggle/input/animeface007/gan.zip/14404.png
# /kaggle/input/animeface007/gan.zip/11545.png
# /kaggle/input/animeface007/gan.zip/5595.png
# /kaggle/input/animeface007/gan.zip/11617.png
# /kaggle/input/animeface007/gan.zip/8962.png
# /kaggle/input/animeface007/gan.zip/17636.png
# /kaggle/input/animeface007/gan.zip/1337.png
# /kaggle/input/animeface007/gan.zip/655.png
# /kaggle/input/animeface007/gan.zip/20431.png
# /kaggle/input/animeface007/gan.zip/9186.png
# /kaggle/input/animeface007/gan.zip/8536.png
# /kaggle/input/animeface007/gan.zip/16895.png
# /kaggle/input/animeface007/gan.zip/8970.png
# /kaggle/input/animeface007/gan.zip/21183.png
# /kaggle/input/animeface007/gan.zip/13638.png
# /kaggle/input/animeface007/gan.zip/18277.png
# /kaggle/input/animeface007/gan.zip/17222.png
# /kaggle/input/animeface007/gan.zip/227.png
# /kaggle/input/animeface007/gan.zip/19351.png
# /kaggle/input/animeface007/gan.zip/18184.png
# /kaggle/input/animeface007/gan.zip/14801.png
# /kaggle/input/animeface007/gan.zip/11460.png
# /kaggle/input/animeface007/gan.zip/19113.png
# /kaggle/input/animeface007/gan.zip/5816.png
# /kaggle/input/animeface007/gan.zip/12177.png
# /kaggle/input/animeface007/gan.zip/18421.png
# /kaggle/input/animeface007/gan.zip/11482.png
# /kaggle/input/animeface007/gan.zip/15781.png
# /kaggle/input/animeface007/gan.zip/13078.png
# /kaggle/input/animeface007/gan.zip/17581.png
# /kaggle/input/animeface007/gan.zip/17690.png
# /kaggle/input/animeface007/gan.zip/762.png
# /kaggle/input/animeface007/gan.zip/13709.png
# /kaggle/input/animeface007/gan.zip/11780.png
# /kaggle/input/animeface007/gan.zip/10213.png
# /kaggle/input/animeface007/gan.zip/9125.png
# /kaggle/input/animeface007/gan.zip/13824.png
# /kaggle/input/animeface007/gan.zip/9994.png
# /kaggle/input/animeface007/gan.zip/8658.png
# /kaggle/input/animeface007/gan.zip/18094.png
# /kaggle/input/animeface007/gan.zip/2803.png
# /kaggle/input/animeface007/gan.zip/12348.png
# /kaggle/input/animeface007/gan.zip/7255.png
# /kaggle/input/animeface007/gan.zip/12508.png
# /kaggle/input/animeface007/gan.zip/10464.png
# /kaggle/input/animeface007/gan.zip/726.png
# /kaggle/input/animeface007/gan.zip/14756.png
# /kaggle/input/animeface007/gan.zip/8377.png
# /kaggle/input/animeface007/gan.zip/9031.png
# /kaggle/input/animeface007/gan.zip/10466.png
# /kaggle/input/animeface007/gan.zip/19734.png
# /kaggle/input/animeface007/gan.zip/8930.png
# /kaggle/input/animeface007/gan.zip/15930.png
# /kaggle/input/animeface007/gan.zip/2199.png
# /kaggle/input/animeface007/gan.zip/5858.png
# /kaggle/input/animeface007/gan.zip/11100.png
# /kaggle/input/animeface007/gan.zip/17340.png
# /kaggle/input/animeface007/gan.zip/5543.png
# /kaggle/input/animeface007/gan.zip/19257.png
# /kaggle/input/animeface007/gan.zip/1630.png
# /kaggle/input/animeface007/gan.zip/10920.png
# /kaggle/input/animeface007/gan.zip/8569.png
# /kaggle/input/animeface007/gan.zip/5898.png
# /kaggle/input/animeface007/gan.zip/19453.png
# /kaggle/input/animeface007/gan.zip/17836.png
# /kaggle/input/animeface007/gan.zip/19070.png
# /kaggle/input/animeface007/gan.zip/16634.png
# /kaggle/input/animeface007/gan.zip/15798.png
# /kaggle/input/animeface007/gan.zip/8660.png
# /kaggle/input/animeface007/gan.zip/13514.png
# /kaggle/input/animeface007/gan.zip/11176.png
# /kaggle/input/animeface007/gan.zip/20523.png
# /kaggle/input/animeface007/gan.zip/19851.png
# /kaggle/input/animeface007/gan.zip/16419.png
# /kaggle/input/animeface007/gan.zip/5831.png
# /kaggle/input/animeface007/gan.zip/2920.png
# /kaggle/input/animeface007/gan.zip/238.png
# /kaggle/input/animeface007/gan.zip/10942.png
# /kaggle/input/animeface007/gan.zip/13961.png
# /kaggle/input/animeface007/gan.zip/9975.png
# /kaggle/input/animeface007/gan.zip/13826.png
# /kaggle/input/animeface007/gan.zip/12261.png
# /kaggle/input/animeface007/gan.zip/10547.png
# /kaggle/input/animeface007/gan.zip/21444.png
# /kaggle/input/animeface007/gan.zip/3728.png
# /kaggle/input/animeface007/gan.zip/3070.png
# /kaggle/input/animeface007/gan.zip/11437.png
# /kaggle/input/animeface007/gan.zip/6910.png
# /kaggle/input/animeface007/gan.zip/19458.png
# /kaggle/input/animeface007/gan.zip/11765.png
# /kaggle/input/animeface007/gan.zip/8364.png
# /kaggle/input/animeface007/gan.zip/19656.png
# /kaggle/input/animeface007/gan.zip/9955.png
# /kaggle/input/animeface007/gan.zip/17936.png
# /kaggle/input/animeface007/gan.zip/61.png
# /kaggle/input/animeface007/gan.zip/12451.png
# /kaggle/input/animeface007/gan.zip/13526.png
# /kaggle/input/animeface007/gan.zip/10713.png
# /kaggle/input/animeface007/gan.zip/2731.png
# /kaggle/input/animeface007/gan.zip/11454.png
# /kaggle/input/animeface007/gan.zip/6158.png
# /kaggle/input/animeface007/gan.zip/15279.png
# /kaggle/input/animeface007/gan.zip/377.png
# /kaggle/input/animeface007/gan.zip/10492.png
# /kaggle/input/animeface007/gan.zip/5391.png
# /kaggle/input/animeface007/gan.zip/8793.png
# /kaggle/input/animeface007/gan.zip/18832.png
# /kaggle/input/animeface007/gan.zip/4554.png
# /kaggle/input/animeface007/gan.zip/17089.png
# /kaggle/input/animeface007/gan.zip/15004.png
# /kaggle/input/animeface007/gan.zip/12267.png
# /kaggle/input/animeface007/gan.zip/19526.png
# /kaggle/input/animeface007/gan.zip/6295.png
# /kaggle/input/animeface007/gan.zip/8295.png
# /kaggle/input/animeface007/gan.zip/18356.png
# /kaggle/input/animeface007/gan.zip/15938.png
# /kaggle/input/animeface007/gan.zip/16422.png
# /kaggle/input/animeface007/gan.zip/17422.png
# /kaggle/input/animeface007/gan.zip/7349.png
# /kaggle/input/animeface007/gan.zip/16938.png
# /kaggle/input/animeface007/gan.zip/7635.png
# /kaggle/input/animeface007/gan.zip/12855.png
# /kaggle/input/animeface007/gan.zip/17842.png
# /kaggle/input/animeface007/gan.zip/4418.png
# /kaggle/input/animeface007/gan.zip/8610.png
# /kaggle/input/animeface007/gan.zip/17466.png
# /kaggle/input/animeface007/gan.zip/21215.png
# /kaggle/input/animeface007/gan.zip/10167.png
# /kaggle/input/animeface007/gan.zip/19652.png
# /kaggle/input/animeface007/gan.zip/16505.png
# /kaggle/input/animeface007/gan.zip/9486.png
# /kaggle/input/animeface007/gan.zip/15858.png
# /kaggle/input/animeface007/gan.zip/18491.png
# /kaggle/input/animeface007/gan.zip/1961.png
# /kaggle/input/animeface007/gan.zip/17056.png
# /kaggle/input/animeface007/gan.zip/7331.png
# /kaggle/input/animeface007/gan.zip/20831.png
# /kaggle/input/animeface007/gan.zip/1798.png
# /kaggle/input/animeface007/gan.zip/17109.png
# /kaggle/input/animeface007/gan.zip/13380.png
# /kaggle/input/animeface007/gan.zip/17818.png
# /kaggle/input/animeface007/gan.zip/7608.png
# /kaggle/input/animeface007/gan.zip/8473.png
# /kaggle/input/animeface007/gan.zip/4864.png
# /kaggle/input/animeface007/gan.zip/17807.png
# /kaggle/input/animeface007/gan.zip/18993.png
# /kaggle/input/animeface007/gan.zip/18372.png
# /kaggle/input/animeface007/gan.zip/12724.png
# /kaggle/input/animeface007/gan.zip/2324.png
# /kaggle/input/animeface007/gan.zip/13976.png
# /kaggle/input/animeface007/gan.zip/16396.png
# /kaggle/input/animeface007/gan.zip/14813.png
# /kaggle/input/animeface007/gan.zip/19720.png
# /kaggle/input/animeface007/gan.zip/14589.png
# /kaggle/input/animeface007/gan.zip/15214.png
# /kaggle/input/animeface007/gan.zip/6626.png
# /kaggle/input/animeface007/gan.zip/581.png
# /kaggle/input/animeface007/gan.zip/1782.png
# /kaggle/input/animeface007/gan.zip/9588.png
# /kaggle/input/animeface007/gan.zip/6887.png
# /kaggle/input/animeface007/gan.zip/222.png
# /kaggle/input/animeface007/gan.zip/12748.png
# /kaggle/input/animeface007/gan.zip/15873.png
# /kaggle/input/animeface007/gan.zip/330.png
# /kaggle/input/animeface007/gan.zip/16733.png
# /kaggle/input/animeface007/gan.zip/16990.png
# /kaggle/input/animeface007/gan.zip/17540.png
# /kaggle/input/animeface007/gan.zip/6851.png
# /kaggle/input/animeface007/gan.zip/17612.png
# /kaggle/input/animeface007/gan.zip/13594.png
# /kaggle/input/animeface007/gan.zip/5038.png
# /kaggle/input/animeface007/gan.zip/16556.png
# /kaggle/input/animeface007/gan.zip/2742.png
# /kaggle/input/animeface007/gan.zip/511.png
# /kaggle/input/animeface007/gan.zip/16274.png
# /kaggle/input/animeface007/gan.zip/10483.png
# /kaggle/input/animeface007/gan.zip/579.png
# /kaggle/input/animeface007/gan.zip/14642.png
# /kaggle/input/animeface007/gan.zip/9565.png
# /kaggle/input/animeface007/gan.zip/6337.png
# /kaggle/input/animeface007/gan.zip/17224.png
# /kaggle/input/animeface007/gan.zip/13643.png
# /kaggle/input/animeface007/gan.zip/15487.png
# /kaggle/input/animeface007/gan.zip/15300.png
# /kaggle/input/animeface007/gan.zip/5957.png
# /kaggle/input/animeface007/gan.zip/8507.png
# /kaggle/input/animeface007/gan.zip/6812.png
# /kaggle/input/animeface007/gan.zip/18455.png
# /kaggle/input/animeface007/gan.zip/6802.png
# /kaggle/input/animeface007/gan.zip/7975.png
# /kaggle/input/animeface007/gan.zip/4127.png
# /kaggle/input/animeface007/gan.zip/278.png
# /kaggle/input/animeface007/gan.zip/18606.png
# /kaggle/input/animeface007/gan.zip/4236.png
# /kaggle/input/animeface007/gan.zip/2146.png
# /kaggle/input/animeface007/gan.zip/21248.png
# /kaggle/input/animeface007/gan.zip/16212.png
# /kaggle/input/animeface007/gan.zip/10431.png
# /kaggle/input/animeface007/gan.zip/6863.png
# /kaggle/input/animeface007/gan.zip/1863.png
# /kaggle/input/animeface007/gan.zip/14944.png
# /kaggle/input/animeface007/gan.zip/927.png
# /kaggle/input/animeface007/gan.zip/7275.png
# /kaggle/input/animeface007/gan.zip/20080.png
# /kaggle/input/animeface007/gan.zip/14826.png
# /kaggle/input/animeface007/gan.zip/303.png
# /kaggle/input/animeface007/gan.zip/19543.png
# /kaggle/input/animeface007/gan.zip/21335.png
# /kaggle/input/animeface007/gan.zip/3921.png
# /kaggle/input/animeface007/gan.zip/21080.png
# /kaggle/input/animeface007/gan.zip/17037.png
# /kaggle/input/animeface007/gan.zip/37.png
# /kaggle/input/animeface007/gan.zip/8454.png
# /kaggle/input/animeface007/gan.zip/231.png
# /kaggle/input/animeface007/gan.zip/1048.png
# /kaggle/input/animeface007/gan.zip/2367.png
# /kaggle/input/animeface007/gan.zip/20295.png
# /kaggle/input/animeface007/gan.zip/21380.png
# /kaggle/input/animeface007/gan.zip/8440.png
# /kaggle/input/animeface007/gan.zip/11884.png
# /kaggle/input/animeface007/gan.zip/6852.png
# /kaggle/input/animeface007/gan.zip/11034.png
# /kaggle/input/animeface007/gan.zip/2559.png
# /kaggle/input/animeface007/gan.zip/11275.png
# /kaggle/input/animeface007/gan.zip/5908.png
# /kaggle/input/animeface007/gan.zip/18753.png
# /kaggle/input/animeface007/gan.zip/645.png
# /kaggle/input/animeface007/gan.zip/16248.png
# /kaggle/input/animeface007/gan.zip/10481.png
# /kaggle/input/animeface007/gan.zip/11938.png
# /kaggle/input/animeface007/gan.zip/19271.png
# /kaggle/input/animeface007/gan.zip/15309.png
# /kaggle/input/animeface007/gan.zip/9303.png
# /kaggle/input/animeface007/gan.zip/19420.png
# /kaggle/input/animeface007/gan.zip/21025.png
# /kaggle/input/animeface007/gan.zip/9845.png
# /kaggle/input/animeface007/gan.zip/14320.png
# /kaggle/input/animeface007/gan.zip/10728.png
# /kaggle/input/animeface007/gan.zip/15554.png
# /kaggle/input/animeface007/gan.zip/2270.png
# /kaggle/input/animeface007/gan.zip/18696.png
# /kaggle/input/animeface007/gan.zip/13053.png
# /kaggle/input/animeface007/gan.zip/1703.png
# /kaggle/input/animeface007/gan.zip/348.png
# /kaggle/input/animeface007/gan.zip/5731.png
# /kaggle/input/animeface007/gan.zip/6108.png
# /kaggle/input/animeface007/gan.zip/16561.png
# /kaggle/input/animeface007/gan.zip/21184.png
# /kaggle/input/animeface007/gan.zip/3959.png
# /kaggle/input/animeface007/gan.zip/20675.png
# /kaggle/input/animeface007/gan.zip/21103.png
# /kaggle/input/animeface007/gan.zip/6587.png
# /kaggle/input/animeface007/gan.zip/10198.png
# /kaggle/input/animeface007/gan.zip/16965.png
# /kaggle/input/animeface007/gan.zip/7681.png
# /kaggle/input/animeface007/gan.zip/16403.png
# /kaggle/input/animeface007/gan.zip/5501.png
# /kaggle/input/animeface007/gan.zip/14719.png
# /kaggle/input/animeface007/gan.zip/5802.png
# /kaggle/input/animeface007/gan.zip/20939.png
# /kaggle/input/animeface007/gan.zip/3372.png
# /kaggle/input/animeface007/gan.zip/4444.png
# /kaggle/input/animeface007/gan.zip/5620.png
# /kaggle/input/animeface007/gan.zip/7490.png
# /kaggle/input/animeface007/gan.zip/4326.png
# /kaggle/input/animeface007/gan.zip/17847.png
# /kaggle/input/animeface007/gan.zip/449.png
# /kaggle/input/animeface007/gan.zip/19044.png
# /kaggle/input/animeface007/gan.zip/3960.png
# /kaggle/input/animeface007/gan.zip/3602.png
# /kaggle/input/animeface007/gan.zip/12699.png
# /kaggle/input/animeface007/gan.zip/2718.png
# /kaggle/input/animeface007/gan.zip/5629.png
# /kaggle/input/animeface007/gan.zip/7791.png
# /kaggle/input/animeface007/gan.zip/21288.png
# /kaggle/input/animeface007/gan.zip/13748.png
# /kaggle/input/animeface007/gan.zip/5378.png
# /kaggle/input/animeface007/gan.zip/9327.png
# /kaggle/input/animeface007/gan.zip/3924.png
# /kaggle/input/animeface007/gan.zip/20203.png
# /kaggle/input/animeface007/gan.zip/5468.png
# /kaggle/input/animeface007/gan.zip/20366.png
# /kaggle/input/animeface007/gan.zip/16492.png
# /kaggle/input/animeface007/gan.zip/17911.png
# /kaggle/input/animeface007/gan.zip/18145.png
# /kaggle/input/animeface007/gan.zip/6509.png
# /kaggle/input/animeface007/gan.zip/12516.png
# /kaggle/input/animeface007/gan.zip/20797.png
# /kaggle/input/animeface007/gan.zip/19775.png
# /kaggle/input/animeface007/gan.zip/20298.png
# /kaggle/input/animeface007/gan.zip/18349.png
# /kaggle/input/animeface007/gan.zip/4303.png
# /kaggle/input/animeface007/gan.zip/15993.png
# /kaggle/input/animeface007/gan.zip/6258.png
# /kaggle/input/animeface007/gan.zip/6408.png
# /kaggle/input/animeface007/gan.zip/2779.png
# /kaggle/input/animeface007/gan.zip/4738.png
# /kaggle/input/animeface007/gan.zip/14579.png
# /kaggle/input/animeface007/gan.zip/20993.png
# /kaggle/input/animeface007/gan.zip/353.png
# /kaggle/input/animeface007/gan.zip/13443.png
# /kaggle/input/animeface007/gan.zip/4463.png
# /kaggle/input/animeface007/gan.zip/7155.png
# /kaggle/input/animeface007/gan.zip/7124.png
# /kaggle/input/animeface007/gan.zip/14921.png
# /kaggle/input/animeface007/gan.zip/14759.png
# /kaggle/input/animeface007/gan.zip/16826.png
# /kaggle/input/animeface007/gan.zip/20578.png
# /kaggle/input/animeface007/gan.zip/3777.png
# /kaggle/input/animeface007/gan.zip/5694.png
# /kaggle/input/animeface007/gan.zip/14825.png
# /kaggle/input/animeface007/gan.zip/18100.png
# /kaggle/input/animeface007/gan.zip/11845.png
# /kaggle/input/animeface007/gan.zip/15018.png
# /kaggle/input/animeface007/gan.zip/13547.png
# /kaggle/input/animeface007/gan.zip/17493.png
# /kaggle/input/animeface007/gan.zip/7050.png
# /kaggle/input/animeface007/gan.zip/7072.png
# /kaggle/input/animeface007/gan.zip/12651.png
# /kaggle/input/animeface007/gan.zip/6663.png
# /kaggle/input/animeface007/gan.zip/8601.png
# /kaggle/input/animeface007/gan.zip/4869.png
# /kaggle/input/animeface007/gan.zip/7097.png
# /kaggle/input/animeface007/gan.zip/6122.png
# /kaggle/input/animeface007/gan.zip/16404.png
# /kaggle/input/animeface007/gan.zip/20304.png
# /kaggle/input/animeface007/gan.zip/7657.png
# /kaggle/input/animeface007/gan.zip/2645.png
# /kaggle/input/animeface007/gan.zip/17564.png
# /kaggle/input/animeface007/gan.zip/14416.png
# /kaggle/input/animeface007/gan.zip/13286.png
# /kaggle/input/animeface007/gan.zip/18332.png
# /kaggle/input/animeface007/gan.zip/12922.png
# /kaggle/input/animeface007/gan.zip/7921.png
# /kaggle/input/animeface007/gan.zip/7794.png
# /kaggle/input/animeface007/gan.zip/12385.png
# /kaggle/input/animeface007/gan.zip/20401.png
# /kaggle/input/animeface007/gan.zip/15330.png
# /kaggle/input/animeface007/gan.zip/20596.png
# /kaggle/input/animeface007/gan.zip/14650.png
# /kaggle/input/animeface007/gan.zip/6143.png
# /kaggle/input/animeface007/gan.zip/7825.png
# /kaggle/input/animeface007/gan.zip/3539.png
# /kaggle/input/animeface007/gan.zip/9141.png
# /kaggle/input/animeface007/gan.zip/11860.png
# /kaggle/input/animeface007/gan.zip/3884.png
# /kaggle/input/animeface007/gan.zip/7266.png
# /kaggle/input/animeface007/gan.zip/7777.png
# /kaggle/input/animeface007/gan.zip/5414.png
# /kaggle/input/animeface007/gan.zip/5461.png
# /kaggle/input/animeface007/gan.zip/10784.png
# /kaggle/input/animeface007/gan.zip/15104.png
# /kaggle/input/animeface007/gan.zip/19766.png
# /kaggle/input/animeface007/gan.zip/16689.png
# /kaggle/input/animeface007/gan.zip/3375.png
# /kaggle/input/animeface007/gan.zip/3770.png
# /kaggle/input/animeface007/gan.zip/621.png
# /kaggle/input/animeface007/gan.zip/13664.png
# /kaggle/input/animeface007/gan.zip/19930.png
# /kaggle/input/animeface007/gan.zip/11135.png
# /kaggle/input/animeface007/gan.zip/5422.png
# /kaggle/input/animeface007/gan.zip/8451.png
# /kaggle/input/animeface007/gan.zip/13546.png
# /kaggle/input/animeface007/gan.zip/2134.png
# /kaggle/input/animeface007/gan.zip/16329.png
# /kaggle/input/animeface007/gan.zip/16194.png
# /kaggle/input/animeface007/gan.zip/9485.png
# /kaggle/input/animeface007/gan.zip/3351.png
# /kaggle/input/animeface007/gan.zip/5361.png
# /kaggle/input/animeface007/gan.zip/20566.png
# /kaggle/input/animeface007/gan.zip/18362.png
# /kaggle/input/animeface007/gan.zip/13960.png
# /kaggle/input/animeface007/gan.zip/14394.png
# /kaggle/input/animeface007/gan.zip/12760.png
# /kaggle/input/animeface007/gan.zip/14134.png
# /kaggle/input/animeface007/gan.zip/21071.png
# /kaggle/input/animeface007/gan.zip/5518.png
# /kaggle/input/animeface007/gan.zip/15205.png
# /kaggle/input/animeface007/gan.zip/8860.png
# /kaggle/input/animeface007/gan.zip/9634.png
# /kaggle/input/animeface007/gan.zip/20226.png
# /kaggle/input/animeface007/gan.zip/16591.png
# /kaggle/input/animeface007/gan.zip/11213.png
# /kaggle/input/animeface007/gan.zip/3450.png
# /kaggle/input/animeface007/gan.zip/15608.png
# /kaggle/input/animeface007/gan.zip/6375.png
# /kaggle/input/animeface007/gan.zip/14157.png
# /kaggle/input/animeface007/gan.zip/7688.png
# /kaggle/input/animeface007/gan.zip/6033.png
# /kaggle/input/animeface007/gan.zip/12467.png
# /kaggle/input/animeface007/gan.zip/10977.png
# /kaggle/input/animeface007/gan.zip/7965.png
# /kaggle/input/animeface007/gan.zip/21118.png
# /kaggle/input/animeface007/gan.zip/20892.png
# /kaggle/input/animeface007/gan.zip/7408.png
# /kaggle/input/animeface007/gan.zip/11393.png
# /kaggle/input/animeface007/gan.zip/19855.png
# /kaggle/input/animeface007/gan.zip/21449.png
# /kaggle/input/animeface007/gan.zip/4699.png
# /kaggle/input/animeface007/gan.zip/1726.png
# /kaggle/input/animeface007/gan.zip/7487.png
# /kaggle/input/animeface007/gan.zip/9629.png
# /kaggle/input/animeface007/gan.zip/15434.png
# /kaggle/input/animeface007/gan.zip/148.png
# /kaggle/input/animeface007/gan.zip/19204.png
# /kaggle/input/animeface007/gan.zip/11003.png
# /kaggle/input/animeface007/gan.zip/7675.png
# /kaggle/input/animeface007/gan.zip/10345.png
# /kaggle/input/animeface007/gan.zip/12320.png
# /kaggle/input/animeface007/gan.zip/10215.png
# /kaggle/input/animeface007/gan.zip/5612.png
# /kaggle/input/animeface007/gan.zip/13290.png
# /kaggle/input/animeface007/gan.zip/12125.png
# /kaggle/input/animeface007/gan.zip/990.png
# /kaggle/input/animeface007/gan.zip/2844.png
# /kaggle/input/animeface007/gan.zip/13308.png
# /kaggle/input/animeface007/gan.zip/12899.png
# /kaggle/input/animeface007/gan.zip/7955.png
# /kaggle/input/animeface007/gan.zip/17673.png
# /kaggle/input/animeface007/gan.zip/16730.png
# /kaggle/input/animeface007/gan.zip/10612.png
# /kaggle/input/animeface007/gan.zip/10544.png
# /kaggle/input/animeface007/gan.zip/403.png
# /kaggle/input/animeface007/gan.zip/18637.png
# /kaggle/input/animeface007/gan.zip/18768.png
# /kaggle/input/animeface007/gan.zip/3632.png
# /kaggle/input/animeface007/gan.zip/20330.png
# /kaggle/input/animeface007/gan.zip/17165.png
# /kaggle/input/animeface007/gan.zip/2661.png
# /kaggle/input/animeface007/gan.zip/16745.png
# /kaggle/input/animeface007/gan.zip/3622.png
# /kaggle/input/animeface007/gan.zip/19536.png
# /kaggle/input/animeface007/gan.zip/19141.png
# /kaggle/input/animeface007/gan.zip/18376.png
# /kaggle/input/animeface007/gan.zip/15428.png
# /kaggle/input/animeface007/gan.zip/18266.png
# /kaggle/input/animeface007/gan.zip/4298.png
# /kaggle/input/animeface007/gan.zip/3702.png
# /kaggle/input/animeface007/gan.zip/3068.png
# /kaggle/input/animeface007/gan.zip/12983.png
# /kaggle/input/animeface007/gan.zip/6991.png
# /kaggle/input/animeface007/gan.zip/9971.png
# /kaggle/input/animeface007/gan.zip/1590.png
# /kaggle/input/animeface007/gan.zip/21481.png
# /kaggle/input/animeface007/gan.zip/20955.png
# /kaggle/input/animeface007/gan.zip/5174.png
# /kaggle/input/animeface007/gan.zip/14715.png
# /kaggle/input/animeface007/gan.zip/8299.png
# /kaggle/input/animeface007/gan.zip/8320.png
# /kaggle/input/animeface007/gan.zip/13085.png
# /kaggle/input/animeface007/gan.zip/15017.png
# /kaggle/input/animeface007/gan.zip/21222.png
# /kaggle/input/animeface007/gan.zip/14151.png
# /kaggle/input/animeface007/gan.zip/1995.png
# /kaggle/input/animeface007/gan.zip/16920.png
# /kaggle/input/animeface007/gan.zip/20130.png
# /kaggle/input/animeface007/gan.zip/17435.png
# /kaggle/input/animeface007/gan.zip/2121.png
# /kaggle/input/animeface007/gan.zip/8816.png
# /kaggle/input/animeface007/gan.zip/21395.png
# /kaggle/input/animeface007/gan.zip/16405.png
# /kaggle/input/animeface007/gan.zip/21343.png
# /kaggle/input/animeface007/gan.zip/6450.png
# /kaggle/input/animeface007/gan.zip/8354.png
# /kaggle/input/animeface007/gan.zip/3366.png
# /kaggle/input/animeface007/gan.zip/11914.png
# /kaggle/input/animeface007/gan.zip/9177.png
# /kaggle/input/animeface007/gan.zip/12697.png
# /kaggle/input/animeface007/gan.zip/3709.png
# /kaggle/input/animeface007/gan.zip/20726.png
# /kaggle/input/animeface007/gan.zip/19956.png
# /kaggle/input/animeface007/gan.zip/3296.png
# /kaggle/input/animeface007/gan.zip/5993.png
# /kaggle/input/animeface007/gan.zip/14972.png
# /kaggle/input/animeface007/gan.zip/8201.png
# /kaggle/input/animeface007/gan.zip/1855.png
# /kaggle/input/animeface007/gan.zip/3107.png
# /kaggle/input/animeface007/gan.zip/19528.png
# /kaggle/input/animeface007/gan.zip/4847.png
# /kaggle/input/animeface007/gan.zip/16964.png
# /kaggle/input/animeface007/gan.zip/12254.png
# /kaggle/input/animeface007/gan.zip/8956.png
# /kaggle/input/animeface007/gan.zip/4761.png
# /kaggle/input/animeface007/gan.zip/1813.png
# /kaggle/input/animeface007/gan.zip/6506.png
# /kaggle/input/animeface007/gan.zip/1000.png
# /kaggle/input/animeface007/gan.zip/20823.png
# /kaggle/input/animeface007/gan.zip/16799.png
# /kaggle/input/animeface007/gan.zip/9719.png
# /kaggle/input/animeface007/gan.zip/13155.png
# /kaggle/input/animeface007/gan.zip/20902.png
# /kaggle/input/animeface007/gan.zip/9725.png
# /kaggle/input/animeface007/gan.zip/9953.png
# /kaggle/input/animeface007/gan.zip/20042.png
# /kaggle/input/animeface007/gan.zip/12889.png
# /kaggle/input/animeface007/gan.zip/8594.png
# /kaggle/input/animeface007/gan.zip/4957.png
# /kaggle/input/animeface007/gan.zip/12574.png
# /kaggle/input/animeface007/gan.zip/10301.png
# /kaggle/input/animeface007/gan.zip/19476.png
# /kaggle/input/animeface007/gan.zip/10841.png
# /kaggle/input/animeface007/gan.zip/5674.png
# /kaggle/input/animeface007/gan.zip/18850.png
# /kaggle/input/animeface007/gan.zip/18557.png
# /kaggle/input/animeface007/gan.zip/16923.png
# /kaggle/input/animeface007/gan.zip/7708.png
# /kaggle/input/animeface007/gan.zip/10016.png
# /kaggle/input/animeface007/gan.zip/2346.png
# /kaggle/input/animeface007/gan.zip/4309.png
# /kaggle/input/animeface007/gan.zip/18990.png
# /kaggle/input/animeface007/gan.zip/20648.png
# /kaggle/input/animeface007/gan.zip/12590.png
# /kaggle/input/animeface007/gan.zip/15417.png
# /kaggle/input/animeface007/gan.zip/2269.png
# /kaggle/input/animeface007/gan.zip/5657.png
# /kaggle/input/animeface007/gan.zip/9713.png
# /kaggle/input/animeface007/gan.zip/19869.png
# /kaggle/input/animeface007/gan.zip/7456.png
# /kaggle/input/animeface007/gan.zip/15543.png
# /kaggle/input/animeface007/gan.zip/18443.png
# /kaggle/input/animeface007/gan.zip/9412.png
# /kaggle/input/animeface007/gan.zip/13244.png
# /kaggle/input/animeface007/gan.zip/4226.png
# ...
# /kaggle/input/animeface007/gan.zip/data/3945.png
# /kaggle/input/animeface007/gan.zip/data/10744.png
# /kaggle/input/animeface007/gan.zip/data/9612.png
# /kaggle/input/animeface007/gan.zip/data/15706.png
# /kaggle/input/animeface007/gan.zip/data/518.png
# /kaggle/input/animeface007/gan.zip/data/21255.png
# /kaggle/input/animeface007/gan.zip/data/7045.png
# /kaggle/input/animeface007/gan.zip/data/3050.png
# /kaggle/input/animeface007/gan.zip/data/17253.png
# /kaggle/input/animeface007/gan.zip/data/14872.png
# /kaggle/input/animeface007/gan.zip/data/19231.png
# /kaggle/input/animeface007/gan.zip/data/14570.png
# /kaggle/input/animeface007/gan.zip/data/2155.png
# /kaggle/input/animeface007/gan.zip/data/19435.png
# /kaggle/input/animeface007/gan.zip/data/1602.png
# /kaggle/input/animeface007/gan.zip/data/14741.png
# /kaggle/input/animeface007/gan.zip/data/17379.png
# /kaggle/input/animeface007/gan.zip/data/18553.png
# /kaggle/input/animeface007/gan.zip/data/14303.png
# /kaggle/input/animeface007/gan.zip/data/2918.png
# /kaggle/input/animeface007/gan.zip/data/18855.png
# /kaggle/input/animeface007/gan.zip/data/16378.png
# /kaggle/input/animeface007/gan.zip/data/18531.png
# /kaggle/input/animeface007/gan.zip/data/19444.png
# /kaggle/input/animeface007/gan.zip/data/8899.png
# /kaggle/input/animeface007/gan.zip/data/20786.png
# /kaggle/input/animeface007/gan.zip/data/17543.png
# /kaggle/input/animeface007/gan.zip/data/8766.png
# /kaggle/input/animeface007/gan.zip/data/957.png
# /kaggle/input/animeface007/gan.zip/data/21516.png
# /kaggle/input/animeface007/gan.zip/data/18808.png
# /kaggle/input/animeface007/gan.zip/data/11896.png
# /kaggle/input/animeface007/gan.zip/data/16207.png
# /kaggle/input/animeface007/gan.zip/data/13365.png
# /kaggle/input/animeface007/gan.zip/data/7924.png
# /kaggle/input/animeface007/gan.zip/data/8848.png
# /kaggle/input/animeface007/gan.zip/data/5751.png
# /kaggle/input/animeface007/gan.zip/data/3657.png
# /kaggle/input/animeface007/gan.zip/data/17740.png
# /kaggle/input/animeface007/gan.zip/data/15900.png
# /kaggle/input/animeface007/gan.zip/data/5285.png
# /kaggle/input/animeface007/gan.zip/data/8765.png
# /kaggle/input/animeface007/gan.zip/data/15030.png
# /kaggle/input/animeface007/gan.zip/data/3935.png
# /kaggle/input/animeface007/gan.zip/data/8296.png
# /kaggle/input/animeface007/gan.zip/data/5199.png
# /kaggle/input/animeface007/gan.zip/data/14272.png
# /kaggle/input/animeface007/gan.zip/data/11977.png
# /kaggle/input/animeface007/gan.zip/data/7899.png
# /kaggle/input/animeface007/gan.zip/data/8272.png
# /kaggle/input/animeface007/gan.zip/data/19409.png
# /kaggle/input/animeface007/gan.zip/data/15593.png
# /kaggle/input/animeface007/gan.zip/data/10476.png
# /kaggle/input/animeface007/gan.zip/data/3679.png
# /kaggle/input/animeface007/gan.zip/data/9653.png
# /kaggle/input/animeface007/gan.zip/data/1876.png
# /kaggle/input/animeface007/gan.zip/data/15753.png
# /kaggle/input/animeface007/gan.zip/data/3336.png
# /kaggle/input/animeface007/gan.zip/data/4112.png
# /kaggle/input/animeface007/gan.zip/data/21022.png
# /kaggle/input/animeface007/gan.zip/data/10725.png
# /kaggle/input/animeface007/gan.zip/data/14405.png
# /kaggle/input/animeface007/gan.zip/data/3468.png
# /kaggle/input/animeface007/gan.zip/data/7064.png
# /kaggle/input/animeface007/gan.zip/data/9249.png
# /kaggle/input/animeface007/gan.zip/data/11987.png
# /kaggle/input/animeface007/gan.zip/data/6064.png
# /kaggle/input/animeface007/gan.zip/data/11870.png
# /kaggle/input/animeface007/gan.zip/data/226.png
# /kaggle/input/animeface007/gan.zip/data/13631.png
# /kaggle/input/animeface007/gan.zip/data/5075.png
# /kaggle/input/animeface007/gan.zip/data/18889.png
# /kaggle/input/animeface007/gan.zip/data/1493.png
# /kaggle/input/animeface007/gan.zip/data/19941.png
# /kaggle/input/animeface007/gan.zip/data/4888.png
# /kaggle/input/animeface007/gan.zip/data/3735.png
# /kaggle/input/animeface007/gan.zip/data/7091.png
# /kaggle/input/animeface007/gan.zip/data/9500.png
# /kaggle/input/animeface007/gan.zip/data/12088.png
# /kaggle/input/animeface007/gan.zip/data/13125.png
# /kaggle/input/animeface007/gan.zip/data/20134.png
# /kaggle/input/animeface007/gan.zip/data/20967.png
# /kaggle/input/animeface007/gan.zip/data/5338.png
# /kaggle/input/animeface007/gan.zip/data/2879.png
# /kaggle/input/animeface007/gan.zip/data/20499.png
# /kaggle/input/animeface007/gan.zip/data/19456.png
# /kaggle/input/animeface007/gan.zip/data/2179.png
# /kaggle/input/animeface007/gan.zip/data/19153.png
# /kaggle/input/animeface007/gan.zip/data/6601.png
# /kaggle/input/animeface007/gan.zip/data/8316.png
# /kaggle/input/animeface007/gan.zip/data/6783.png
# /kaggle/input/animeface007/gan.zip/data/6725.png
# /kaggle/input/animeface007/gan.zip/data/8286.png
# /kaggle/input/animeface007/gan.zip/data/6967.png
# /kaggle/input/animeface007/gan.zip/data/8131.png
# /kaggle/input/animeface007/gan.zip/data/10068.png
# /kaggle/input/animeface007/gan.zip/data/20333.png
# /kaggle/input/animeface007/gan.zip/data/10503.png
# /kaggle/input/animeface007/gan.zip/data/12452.png
# /kaggle/input/animeface007/gan.zip/data/10609.png
# /kaggle/input/animeface007/gan.zip/data/15132.png
# /kaggle/input/animeface007/gan.zip/data/16811.png
# /kaggle/input/animeface007/gan.zip/data/9912.png
# /kaggle/input/animeface007/gan.zip/data/4288.png
# /kaggle/input/animeface007/gan.zip/data/11198.png
# /kaggle/input/animeface007/gan.zip/data/15849.png
# /kaggle/input/animeface007/gan.zip/data/8287.png
# /kaggle/input/animeface007/gan.zip/data/12419.png
# /kaggle/input/animeface007/gan.zip/data/4435.png
# /kaggle/input/animeface007/gan.zip/data/12332.png
# /kaggle/input/animeface007/gan.zip/data/15760.png
# /kaggle/input/animeface007/gan.zip/data/2570.png
# /kaggle/input/animeface007/gan.zip/data/18534.png
# /kaggle/input/animeface007/gan.zip/data/10354.png
# /kaggle/input/animeface007/gan.zip/data/20772.png
# /kaggle/input/animeface007/gan.zip/data/17360.png
# /kaggle/input/animeface007/gan.zip/data/5684.png
# /kaggle/input/animeface007/gan.zip/data/8006.png
# /kaggle/input/animeface007/gan.zip/data/428.png
# /kaggle/input/animeface007/gan.zip/data/12823.png
# /kaggle/input/animeface007/gan.zip/data/16067.png
# /kaggle/input/animeface007/gan.zip/data/18426.png
# /kaggle/input/animeface007/gan.zip/data/3549.png
# /kaggle/input/animeface007/gan.zip/data/14991.png
# /kaggle/input/animeface007/gan.zip/data/19548.png
# /kaggle/input/animeface007/gan.zip/data/10645.png
# /kaggle/input/animeface007/gan.zip/data/6771.png
# /kaggle/input/animeface007/gan.zip/data/18057.png
# /kaggle/input/animeface007/gan.zip/data/14271.png
# /kaggle/input/animeface007/gan.zip/data/12737.png
# /kaggle/input/animeface007/gan.zip/data/8728.png
# /kaggle/input/animeface007/gan.zip/data/3613.png
# /kaggle/input/animeface007/gan.zip/data/15067.png
# /kaggle/input/animeface007/gan.zip/data/2927.png
# /kaggle/input/animeface007/gan.zip/data/4222.png
# /kaggle/input/animeface007/gan.zip/data/2264.png
# /kaggle/input/animeface007/gan.zip/data/15544.png
# /kaggle/input/animeface007/gan.zip/data/17709.png
# /kaggle/input/animeface007/gan.zip/data/16108.png
# /kaggle/input/animeface007/gan.zip/data/7469.png
# /kaggle/input/animeface007/gan.zip/data/14830.png
# /kaggle/input/animeface007/gan.zip/data/5655.png
# /kaggle/input/animeface007/gan.zip/data/217.png
# /kaggle/input/animeface007/gan.zip/data/2964.png
# /kaggle/input/animeface007/gan.zip/data/1424.png
# /kaggle/input/animeface007/gan.zip/data/17884.png
# /kaggle/input/animeface007/gan.zip/data/18648.png
# /kaggle/input/animeface007/gan.zip/data/13098.png
# /kaggle/input/animeface007/gan.zip/data/20090.png
# /kaggle/input/animeface007/gan.zip/data/10470.png
# /kaggle/input/animeface007/gan.zip/data/13121.png
# /kaggle/input/animeface007/gan.zip/data/11062.png
# /kaggle/input/animeface007/gan.zip/data/10835.png
# /kaggle/input/animeface007/gan.zip/data/11471.png
# /kaggle/input/animeface007/gan.zip/data/10837.png
# /kaggle/input/animeface007/gan.zip/data/7585.png
# /kaggle/input/animeface007/gan.zip/data/3484.png
# /kaggle/input/animeface007/gan.zip/data/6252.png
# /kaggle/input/animeface007/gan.zip/data/1710.png
# /kaggle/input/animeface007/gan.zip/data/4410.png
# /kaggle/input/animeface007/gan.zip/data/18948.png
# /kaggle/input/animeface007/gan.zip/data/4258.png
# /kaggle/input/animeface007/gan.zip/data/17826.png
# /kaggle/input/animeface007/gan.zip/data/21001.png
# /kaggle/input/animeface007/gan.zip/data/10640.png
# /kaggle/input/animeface007/gan.zip/data/4396.png
# /kaggle/input/animeface007/gan.zip/data/15073.png
# /kaggle/input/animeface007/gan.zip/data/19173.png
# /kaggle/input/animeface007/gan.zip/data/12380.png
# /kaggle/input/animeface007/gan.zip/data/11931.png
# /kaggle/input/animeface007/gan.zip/data/15867.png
# /kaggle/input/animeface007/gan.zip/data/18973.png
# /kaggle/input/animeface007/gan.zip/data/16089.png
# /kaggle/input/animeface007/gan.zip/data/2652.png
# /kaggle/input/animeface007/gan.zip/data/21013.png
# /kaggle/input/animeface007/gan.zip/data/9934.png
# /kaggle/input/animeface007/gan.zip/data/14160.png
# /kaggle/input/animeface007/gan.zip/data/3656.png
# /kaggle/input/animeface007/gan.zip/data/3266.png
# /kaggle/input/animeface007/gan.zip/data/20476.png
# /kaggle/input/animeface007/gan.zip/data/9843.png
# /kaggle/input/animeface007/gan.zip/data/7948.png
# /kaggle/input/animeface007/gan.zip/data/12122.png
# /kaggle/input/animeface007/gan.zip/data/3029.png
# /kaggle/input/animeface007/gan.zip/data/13074.png
# /kaggle/input/animeface007/gan.zip/data/3749.png
# /kaggle/input/animeface007/gan.zip/data/1330.png
# /kaggle/input/animeface007/gan.zip/data/21316.png
# /kaggle/input/animeface007/gan.zip/data/15751.png
# /kaggle/input/animeface007/gan.zip/data/15435.png
# /kaggle/input/animeface007/gan.zip/data/2708.png
# /kaggle/input/animeface007/gan.zip/data/9817.png
# /kaggle/input/animeface007/gan.zip/data/4663.png
# /kaggle/input/animeface007/gan.zip/data/9074.png
# /kaggle/input/animeface007/gan.zip/data/5161.png
# /kaggle/input/animeface007/gan.zip/data/17003.png
# /kaggle/input/animeface007/gan.zip/data/21049.png
# /kaggle/input/animeface007/gan.zip/data/20147.png
# /kaggle/input/animeface007/gan.zip/data/867.png
# /kaggle/input/animeface007/gan.zip/data/19951.png
# /kaggle/input/animeface007/gan.zip/data/7891.png
# /kaggle/input/animeface007/gan.zip/data/13935.png
# /kaggle/input/animeface007/gan.zip/data/2693.png
# /kaggle/input/animeface007/gan.zip/data/17091.png
# /kaggle/input/animeface007/gan.zip/data/9170.png
# /kaggle/input/animeface007/gan.zip/data/821.png
# /kaggle/input/animeface007/gan.zip/data/18656.png
# /kaggle/input/animeface007/gan.zip/data/16788.png
# /kaggle/input/animeface007/gan.zip/data/494.png
# /kaggle/input/animeface007/gan.zip/data/9532.png
# /kaggle/input/animeface007/gan.zip/data/19878.png
# /kaggle/input/animeface007/gan.zip/data/16679.png
# /kaggle/input/animeface007/gan.zip/data/12815.png
# /kaggle/input/animeface007/gan.zip/data/6742.png
# /kaggle/input/animeface007/gan.zip/data/4962.png
# /kaggle/input/animeface007/gan.zip/data/4256.png
# /kaggle/input/animeface007/gan.zip/data/6191.png
# /kaggle/input/animeface007/gan.zip/data/3737.png
# /kaggle/input/animeface007/gan.zip/data/5514.png
# /kaggle/input/animeface007/gan.zip/data/11011.png
# /kaggle/input/animeface007/gan.zip/data/17061.png
# /kaggle/input/animeface007/gan.zip/data/11338.png
# /kaggle/input/animeface007/gan.zip/data/10407.png
# /kaggle/input/animeface007/gan.zip/data/19744.png
# /kaggle/input/animeface007/gan.zip/data/2383.png
# /kaggle/input/animeface007/gan.zip/data/20970.png
# /kaggle/input/animeface007/gan.zip/data/7028.png
# /kaggle/input/animeface007/gan.zip/data/15665.png
# /kaggle/input/animeface007/gan.zip/data/12689.png
# /kaggle/input/animeface007/gan.zip/data/8613.png
# /kaggle/input/animeface007/gan.zip/data/18501.png
# /kaggle/input/animeface007/gan.zip/data/18249.png
# /kaggle/input/animeface007/gan.zip/data/21218.png
# /kaggle/input/animeface007/gan.zip/data/6072.png
# /kaggle/input/animeface007/gan.zip/data/16179.png
# /kaggle/input/animeface007/gan.zip/data/837.png
# /kaggle/input/animeface007/gan.zip/data/7237.png
# /kaggle/input/animeface007/gan.zip/data/5618.png
# /kaggle/input/animeface007/gan.zip/data/13100.png
# /kaggle/input/animeface007/gan.zip/data/659.png
# /kaggle/input/animeface007/gan.zip/data/2210.png
# /kaggle/input/animeface007/gan.zip/data/12038.png
# /kaggle/input/animeface007/gan.zip/data/3247.png
# /kaggle/input/animeface007/gan.zip/data/3231.png
# /kaggle/input/animeface007/gan.zip/data/5270.png
# /kaggle/input/animeface007/gan.zip/data/20591.png
# /kaggle/input/animeface007/gan.zip/data/3103.png
# /kaggle/input/animeface007/gan.zip/data/4631.png
# /kaggle/input/animeface007/gan.zip/data/20782.png
# /kaggle/input/animeface007/gan.zip/data/5319.png
# /kaggle/input/animeface007/gan.zip/data/6000.png
# /kaggle/input/animeface007/gan.zip/data/5665.png
# /kaggle/input/animeface007/gan.zip/data/4935.png
# /kaggle/input/animeface007/gan.zip/data/8675.png
# /kaggle/input/animeface007/gan.zip/data/418.png
# /kaggle/input/animeface007/gan.zip/data/13027.png
# /kaggle/input/animeface007/gan.zip/data/452.png
# /kaggle/input/animeface007/gan.zip/data/3863.png
# /kaggle/input/animeface007/gan.zip/data/18550.png
# /kaggle/input/animeface007/gan.zip/data/14795.png
# /kaggle/input/animeface007/gan.zip/data/10472.png
# /kaggle/input/animeface007/gan.zip/data/3420.png
# /kaggle/input/animeface007/gan.zip/data/6841.png
# /kaggle/input/animeface007/gan.zip/data/11923.png
# /kaggle/input/animeface007/gan.zip/data/2627.png
# /kaggle/input/animeface007/gan.zip/data/16978.png
# /kaggle/input/animeface007/gan.zip/data/6995.png
# /kaggle/input/animeface007/gan.zip/data/9579.png
# /kaggle/input/animeface007/gan.zip/data/19117.png
# /kaggle/input/animeface007/gan.zip/data/8513.png
# /kaggle/input/animeface007/gan.zip/data/14760.png
# /kaggle/input/animeface007/gan.zip/data/18125.png
# /kaggle/input/animeface007/gan.zip/data/18291.png
# /kaggle/input/animeface007/gan.zip/data/20475.png
# /kaggle/input/animeface007/gan.zip/data/19833.png
# /kaggle/input/animeface007/gan.zip/data/15297.png
# /kaggle/input/animeface007/gan.zip/data/4704.png
# /kaggle/input/animeface007/gan.zip/data/9285.png
# /kaggle/input/animeface007/gan.zip/data/6173.png
# /kaggle/input/animeface007/gan.zip/data/20729.png
# /kaggle/input/animeface007/gan.zip/data/10617.png
# /kaggle/input/animeface007/gan.zip/data/15846.png
# /kaggle/input/animeface007/gan.zip/data/16246.png
# /kaggle/input/animeface007/gan.zip/data/16547.png
# /kaggle/input/animeface007/gan.zip/data/15152.png
# /kaggle/input/animeface007/gan.zip/data/17444.png
# /kaggle/input/animeface007/gan.zip/data/17556.png
# /kaggle/input/animeface007/gan.zip/data/7658.png
# /kaggle/input/animeface007/gan.zip/data/981.png
# /kaggle/input/animeface007/gan.zip/data/948.png
# /kaggle/input/animeface007/gan.zip/data/9704.png
# /kaggle/input/animeface007/gan.zip/data/6461.png
# /kaggle/input/animeface007/gan.zip/data/16926.png
# /kaggle/input/animeface007/gan.zip/data/14334.png
# /kaggle/input/animeface007/gan.zip/data/14411.png
# /kaggle/input/animeface007/gan.zip/data/17395.png
# /kaggle/input/animeface007/gan.zip/data/11733.png
# /kaggle/input/animeface007/gan.zip/data/21113.png
# /kaggle/input/animeface007/gan.zip/data/2392.png
# /kaggle/input/animeface007/gan.zip/data/15816.png
# /kaggle/input/animeface007/gan.zip/data/13957.png
# /kaggle/input/animeface007/gan.zip/data/13785.png
# /kaggle/input/animeface007/gan.zip/data/3926.png
# /kaggle/input/animeface007/gan.zip/data/306.png
# /kaggle/input/animeface007/gan.zip/data/19334.png
# /kaggle/input/animeface007/gan.zip/data/9901.png
# /kaggle/input/animeface007/gan.zip/data/13283.png
# /kaggle/input/animeface007/gan.zip/data/21426.png
# /kaggle/input/animeface007/gan.zip/data/14735.png
# /kaggle/input/animeface007/gan.zip/data/6464.png
# /kaggle/input/animeface007/gan.zip/data/497.png
# /kaggle/input/animeface007/gan.zip/data/4225.png
# /kaggle/input/animeface007/gan.zip/data/20517.png
# /kaggle/input/animeface007/gan.zip/data/5162.png
# /kaggle/input/animeface007/gan.zip/data/2995.png
# /kaggle/input/animeface007/gan.zip/data/304.png
# /kaggle/input/animeface007/gan.zip/data/5562.png
# /kaggle/input/animeface007/gan.zip/data/17138.png
# /kaggle/input/animeface007/gan.zip/data/12060.png
# /kaggle/input/animeface007/gan.zip/data/7013.png
# /kaggle/input/animeface007/gan.zip/data/14107.png
# /kaggle/input/animeface007/gan.zip/data/16486.png
# /kaggle/input/animeface007/gan.zip/data/4164.png

# %%
import os
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
random_seed = 42
torch.manual_seed(random_seed)

# %%
batch_size = 128
NUM_WORKERS = int(os.cpu_count() / 2)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
latent_dim = 100
epochs = 50
OUTPUT_DIR = "./gan_generated_images"
os.makedirs(OUTPUT_DIR, exist_ok=True)
data_dir = '/kaggle/input/animeface007/gan.zip'

# %%
transform = transforms.Compose([
    transforms.Resize((64, 64)),       
    transforms.ToTensor(),            
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  
])

# %%
dataset = ImageFolder(root=data_dir, transform=transform)
dataset_size = len(dataset)
print(dataset_size )
# Out:
# 21551

# %%
train_size = int(0.9 * dataset_size)
val_size = dataset_size - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=NUM_WORKERS)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=NUM_WORKERS)

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1)
        self.fc = nn.Linear(256 * 8 * 8, 1)

    def forward(self, x):
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.conv2(x), 0.2)
        x = F.leaky_relu(self.conv3(x), 0.2)
        x = x.view(-1, 256 * 8 * 8)
        x = self.fc(x)
        return torch.sigmoid(x)

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()
        self.fc = nn.Linear(latent_dim, 256 * 8 * 8)
        self.ct1 = nn.ConvTranspose2d(256, 128, 4, stride=2, padding=1)
        self.ct2 = nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1)
        self.ct3 = nn.ConvTranspose2d(64, 3, 4, stride=2, padding=1)

    def forward(self, x):
        x = self.fc(x)
        x = x.view(-1, 256, 8, 8)
        x = F.relu(self.ct1(x))
        x = F.relu(self.ct2(x))
        x = torch.tanh(self.ct3(x))  # Output in range [-1, 1]
        return x

# %%
from torchvision.utils import save_image
def save_generated_images(generator, latent_dim, epoch, device):
    generator.eval()  # Set generator to evaluation mode
    with torch.no_grad():
        latent_space = torch.randn(16, latent_dim).to(device)  # Generate 16 random samples
        fake_images = generator(latent_space)
        fake_images = (fake_images + 1) / 2  # Rescale to [0, 1] for saving as images
        save_image(fake_images, os.path.join(OUTPUT_DIR, f"epoch_{epoch+1}.png"), nrow=4)
    generator.train()  # Reset generator to training mode

# %%
def train_gan(discriminator, generator, train_loader, latent_dim, epochs, device):
    discriminator.to(device)
    generator.to(device)
    criterion = nn.BCELoss()
    
    # Define the optimizers
    d_optimizer = optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))
    g_optimizer = optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))
    
    # Learning rate schedulers
    scheduler_d = optim.lr_scheduler.StepLR(d_optimizer, step_size=10, gamma=0.5)  # Decay every 10 epochs
    scheduler_g = optim.lr_scheduler.StepLR(g_optimizer, step_size=10, gamma=0.5)  # Decay every 10 epochs

    for epoch in range(epochs):
        for real_images, _ in train_loader:
            real_images = real_images.to(device)

            # Train Discriminator
            d_optimizer.zero_grad()
            real_labels = torch.ones(real_images.size(0), 1).to(device)
            fake_labels = torch.zeros(real_images.size(0), 1).to(device)

            real_outputs = discriminator(real_images)
            d_real_loss = criterion(real_outputs, real_labels)

            latent_space = torch.randn(real_images.size(0), latent_dim).to(device)
            fake_images = generator(latent_space)
            fake_outputs = discriminator(fake_images.detach())
            d_fake_loss = criterion(fake_outputs, fake_labels)

            # Average the discriminator losses
            d_loss = (d_real_loss + d_fake_loss) / 2  # Division by 2
            d_loss.backward()
            d_optimizer.step()

            # Train Generator
            g_optimizer.zero_grad()
            fake_outputs = discriminator(fake_images)
            g_loss = criterion(fake_outputs, real_labels)
            g_loss.backward()
            g_optimizer.step()

        # Update the learning rate using the scheduler
        scheduler_d.step()
        scheduler_g.step()
        if (epoch + 1) % 5 == 0: 
            save_generated_images(generator, latent_dim, epoch, device)
            print(f"Epoch [{epoch+1}/{epochs}], d_loss: {d_loss.item():.4f}, g_loss: {g_loss.item():.4f}")
            print(f"Discriminator learning rate: {scheduler_d.get_last_lr()[0]:.6f}, Generator learning rate: {scheduler_g.get_last_lr()[0]:.6f}")
            print(f"Images saved at epoch {epoch+1}.")
        else:
            print(f"Epoch [{epoch+1}/{epochs}], d_loss: {d_loss.item():.4f}, g_loss: {g_loss.item():.4f}")

discriminator = Discriminator()
generator = Generator(latent_dim)

train_gan(discriminator, generator, train_loader, latent_dim, epochs=epochs, device=device)
# Out:
# Epoch [1/50], d_loss: 0.0815, g_loss: 3.6362
# Epoch [2/50], d_loss: 0.3985, g_loss: 4.1997
# Epoch [3/50], d_loss: 0.3991, g_loss: 2.4592
# Epoch [4/50], d_loss: 0.3832, g_loss: 1.5352
# Epoch [5/50], d_loss: 0.6765, g_loss: 1.6654
# Discriminator learning rate: 0.000200, Generator learning rate: 0.000200
# Images saved at epoch 5.
# Epoch [6/50], d_loss: 0.3266, g_loss: 2.6305
# Epoch [7/50], d_loss: 0.4450, g_loss: 1.5651
# Epoch [8/50], d_loss: 0.4697, g_loss: 2.0047
# Epoch [9/50], d_loss: 0.4780, g_loss: 1.5689
# Epoch [10/50], d_loss: 0.6163, g_loss: 1.1752
# Discriminator learning rate: 0.000100, Generator learning rate: 0.000100
# Images saved at epoch 10.
# Epoch [11/50], d_loss: 0.5537, g_loss: 0.6968
# Epoch [12/50], d_loss: 0.5252, g_loss: 0.8898
# Epoch [13/50], d_loss: 0.5174, g_loss: 1.4479
# Epoch [14/50], d_loss: 0.5328, g_loss: 1.6963
# Epoch [15/50], d_loss: 0.5549, g_loss: 0.9938
# Discriminator learning rate: 0.000100, Generator learning rate: 0.000100
# Images saved at epoch 15.
# Epoch [16/50], d_loss: 0.4909, g_loss: 1.0969
# Epoch [17/50], d_loss: 0.5057, g_loss: 1.1559
# Epoch [18/50], d_loss: 0.5507, g_loss: 1.0943
# Epoch [19/50], d_loss: 0.5918, g_loss: 1.4788
# Epoch [20/50], d_loss: 0.5329, g_loss: 0.8460
# Discriminator learning rate: 0.000050, Generator learning rate: 0.000050
# Images saved at epoch 20.
# Epoch [21/50], d_loss: 0.4485, g_loss: 1.1466
# Epoch [22/50], d_loss: 0.4690, g_loss: 0.9446
# Epoch [23/50], d_loss: 0.4555, g_loss: 1.1657
# Epoch [24/50], d_loss: 0.4057, g_loss: 0.9352
# Epoch [25/50], d_loss: 0.4561, g_loss: 1.1320
# Discriminator learning rate: 0.000050, Generator learning rate: 0.000050
# Images saved at epoch 25.
# Epoch [26/50], d_loss: 0.4044, g_loss: 1.2895
# Epoch [27/50], d_loss: 0.3844, g_loss: 1.9152
# Epoch [28/50], d_loss: 0.4102, g_loss: 1.3507
# Epoch [29/50], d_loss: 0.3716, g_loss: 1.3941
# Epoch [30/50], d_loss: 0.4128, g_loss: 0.9265
# Discriminator learning rate: 0.000025, Generator learning rate: 0.000025
# Images saved at epoch 30.
# Epoch [31/50], d_loss: 0.3785, g_loss: 1.2778
# Epoch [32/50], d_loss: 0.4508, g_loss: 1.0788
# Epoch [33/50], d_loss: 0.4263, g_loss: 1.4448
# Epoch [34/50], d_loss: 0.4146, g_loss: 1.4148
# Epoch [35/50], d_loss: 0.4746, g_loss: 1.4216
# Discriminator learning rate: 0.000025, Generator learning rate: 0.000025
# Images saved at epoch 35.
# Epoch [36/50], d_loss: 0.4312, g_loss: 1.1171
# Epoch [37/50], d_loss: 0.4405, g_loss: 1.2149
# Epoch [38/50], d_loss: 0.3909, g_loss: 1.2652
# Epoch [39/50], d_loss: 0.4392, g_loss: 0.9919
# Epoch [40/50], d_loss: 0.4526, g_loss: 1.4010
# Discriminator learning rate: 0.000013, Generator learning rate: 0.000013
# Images saved at epoch 40.
# Epoch [41/50], d_loss: 0.4524, g_loss: 1.1344
# Epoch [42/50], d_loss: 0.4611, g_loss: 1.0646
# Epoch [43/50], d_loss: 0.4536, g_loss: 1.0483
# Epoch [44/50], d_loss: 0.4137, g_loss: 1.2338
# Epoch [45/50], d_loss: 0.4252, g_loss: 1.2698
# Discriminator learning rate: 0.000013, Generator learning rate: 0.000013
# Images saved at epoch 45.
# Epoch [46/50], d_loss: 0.4551, g_loss: 1.1206
# Epoch [47/50], d_loss: 0.4512, g_loss: 1.1432
# Epoch [48/50], d_loss: 0.3949, g_loss: 1.4099
# Epoch [49/50], d_loss: 0.4428, g_loss: 1.2030
# Epoch [50/50], d_loss: 0.4220, g_loss: 1.0453
# Discriminator learning rate: 0.000006, Generator learning rate: 0.000006
# Images saved at epoch 50.
